# %%
import pandas as pd 
from matplotlib import pyplot as plt 
from typing import Dict, Set

# %%
excel_data: pd.DataFrame = pd.read_excel('Data.xlsx')
excel_data
# Out:
#     Year     Country   Fertility_Rate_Person_Female   Life_Expectancy_Person  \
# 0   1960  Kazakh SSR                          4.530                58.370512
# 1   1961  Kazakh SSR                          4.486                58.503073
# 2   1962  Kazakh SSR                          4.404                58.621756
# 3   1963  Kazakh SSR                          4.341                58.944512
# 4   1964  Kazakh SSR                          4.219                59.157488
# ..   ...         ...                            ...                      ...
# 57  2017  Kazakhstan                          2.750                72.950000
# 58  2018  Kazakhstan                          2.840                73.150000
# 59  2019  Kazakhstan                          2.900                73.180000
# 60  2020  Kazakhstan                          3.130                71.370000
# 61  2021  Kazakhstan                          3.320                70.230000
#
# ...

# %%
kaz_SSR: pd.DataFrame = excel_data.loc[excel_data["Country"] == "Kazakh SSR"]
kaz_SSR
# Out:
#     Year     Country   Fertility_Rate_Person_Female   Life_Expectancy_Person  \
# 0   1960  Kazakh SSR                          4.530                58.370512
# 1   1961  Kazakh SSR                          4.486                58.503073
# 2   1962  Kazakh SSR                          4.404                58.621756
# 3   1963  Kazakh SSR                          4.341                58.944512
# 4   1964  Kazakh SSR                          4.219                59.157488
# 5   1965  Kazakh SSR                          4.111                59.461683
# 6   1966  Kazakh SSR                          4.008                59.699220
# 7   1967  Kazakh SSR                          3.877                59.873415
# 8   1968  Kazakh SSR                          3.681                59.998366
# 9   1969  Kazakh SSR                          3.537                60.191171
# 10  1970  Kazakh SSR                          3.529                60.422976
# ...

# %%
countries: Set[str] = {i for i in excel_data["Country"]}
info_by_countries: Dict[str, pd.DataFrame] = dict.fromkeys(countries)
info_by_countries
# Out:
# {'Kazakh SSR': None, 'Kazakhstan': None}

# %%
for i in info_by_countries:
    info_by_countries[i] = excel_data.loc[excel_data["Country"] == "Kazakhstan" ]
info_by_countries
# Out:
# {'Kazakh SSR':     Year     Country   Fertility_Rate_Person_Female   Life_Expectancy_Person  \
#  31  1991  Kazakhstan                           2.61                    67.60
#  32  1992  Kazakhstan                           2.50                    67.40
#  33  1993  Kazakhstan                           2.30                    65.40
#  34  1994  Kazakhstan                           2.28                    64.90
#  35  1995  Kazakhstan                           2.26                    63.50
#  36  1996  Kazakhstan                           2.13                    63.60
#  37  1997  Kazakhstan                           2.00                    64.00
#  38  1998  Kazakhstan                           1.80                    64.50
#  39  1999  Kazakhstan                           1.80                    65.63
#  40  2000  Kazakhstan                           1.80                    65.45
#  41  2001  Kazakhstan                           1.90                    65.76
# ...

# %%
filt: pd.Series = excel_data[" Life_Expectancy_Person"] >= 72
filt2: pd.Series = excel_data["Country"] == "Kazakhstan"
save_to_excel: pd.DataFrame = excel_data.where(filt & filt2).dropna()
save_to_excel
# Out:
#       Year     Country   Fertility_Rate_Person_Female  \
# 56  2016.0  Kazakhstan                           2.77
# 57  2017.0  Kazakhstan                           2.75
# 58  2018.0  Kazakhstan                           2.84
# 59  2019.0  Kazakhstan                           2.90
#
#      Life_Expectancy_Person   Count_Person_Is_Internet_User_PerCapita  \
# 56                    72.41                                 74.587726
# 57                    72.95                                 76.426748
# 58                    73.15                                 78.903919
# 59                    73.18                                 81.877620
#
#      Growth_Rate_Count_Person   Count_Person
# 56                   1.422046     17794055.0
# 57                   1.360381     18037776.0
# 58                   1.314523     18276452.0
# 59                   1.289608     18513673.0

# %%
# --- bar chart or histogram
print(excel_data["Count_Person"].plot.hist())

plt.xlabel('coefficent')
plt.ylabel('population')
plt.show()


# --- line plots ---
excel_data.plot.line(x="Year", y=" Count_Person_Is_Internet_User_PerCapita")

plt.ylabel('Internet users per capita')
plt.xlabel("Year")
plt.show()


# --- Hex Bin plot ---
excel_data.plot.hexbin(x="Year", y=" Life_Expectancy_Person", gridsize=7, cmap="Reds")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Count_Person'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 2
#       1 # --- bar chart or histogram
# ...
